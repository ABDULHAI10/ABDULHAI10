# %% [markdown]
# <a href="https://colab.research.google.com/github/ABDULHAI10/ABDULHAI10/blob/main/EDA_Session_05_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Load Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read Dataset

# %%
url = "https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/usedcars.csv"

df = pd.read_csv(url)

# %% [markdown]
# ## Explore Data

# %% [markdown]
# ### Reading dataframe

# %%
df
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
#My Practice

# %%
df.shape #150 rows and 6 cols
# Out:
# (150, 6)

# %%
df.dtypes
# Out:
# year             int64
# model           object
# price            int64
# mileage          int64
# color           object
# transmission    object
# dtype: object

# %%
#Check Null or missing values
df.isnull().sum()
# Out:
# year            0
# model           0
# price           0
# mileage         0
# color           0
# transmission    0
# dtype: int64

# %%
#Duplicated
df.duplicated().sum()
# Out:
# 0

# %%
#Conditional Statement
#to check if any of the row is duplicated,
#which can be seen seen but in this context no row is duplciated

df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [year, model, price, mileage, color, transmission]
# Index: []

# %%
#Statistical
df.describe()
# Out:
#               year         price        mileage
# count   150.000000    150.000000     150.000000
# mean   2008.726667  12961.933333   44260.646667
# std       2.200966   3122.481735   26982.104322
# min    2000.000000   3800.000000    4867.000000
# 25%    2008.000000  10995.000000   27200.250000
# 50%    2009.000000  13591.500000   36385.000000
# 75%    2010.000000  14904.500000   55124.500000
# max    2012.000000  21992.000000  151479.000000

# %%
df.describe (include='O') #object is O
# Out:
#        model  color transmission
# count    150    150          150
# unique     3      9            2
# top       SE  Black         AUTO
# freq      78     35          128

# %%
df['model'].value_counts()
# Out:
# model
# SE     78
# SES    49
# SEL    23
# Name: count, dtype: int64

# %%
#to check counts of every object.

# %%
df.columns
# Out:
# Index(['year', 'model', 'price', 'mileage', 'color', 'transmission'], dtype='object')

# %%
#1 This display every object with with their counts as well

#2 eik eik kr k saray cols ko dena time taken hoga tu humne loop apply kra hai.
for col in df.select_dtypes(include="object").columns:
  display(df[col].value_counts())
  print("\n")
# Out:
# model
# SE     78
# SES    49
# SEL    23
# Name: count, dtype: int64
# color
# Black     35
# Silver    32
# Red       25
# Blue      17
# Gray      16
# White     16
# Green      5
# Yellow     3
# Gold       1
# Name: count, dtype: int64
# transmission
# AUTO      128
# MANUAL     22
# Name: count, dtype: int64

# %%
#Unique values for all categorical features

for col in df.select_dtypes(include="object").columns:
  print(col, 'has', df[col].nunique(), 'valaues')
  display(df[col].unique())
  print("\n")
# Out:
# model has 3 valaues
# array(['SEL', 'SE', 'SES'], dtype=object)
# color has 9 valaues
# array(['Yellow', 'Gray', 'Silver', 'White', 'Blue', 'Black', 'Green',
#        'Red', 'Gold'], dtype=object)
# transmission has 2 valaues
# array(['AUTO', 'MANUAL'], dtype=object)

# %%
#For numerical data we use "D I S T R I B U T I O N    P L O T" same like histogram.
#For Categorical data we use "C O U N T"
#For 'B O X  P L O T' => Distribution and spread of data values, columns and outliers

# %%
df.dtypes
# Out:
# year             int64
# model           object
# price            int64
# mileage          int64
# color           object
# transmission    object
# dtype: object

# %%
# We have three columns of int64
# Year Price Mileage

# %%
# distribution plot
# sns.distplot => line + histogram


# sns.histplot => histogram
#       and if u write kde as params
# sns.histplot(kde = true) it will show the line as well.

# %%
sns.distplot(df['year'])
plt.show()
# Out:
# <ipython-input-89-d3447e322739>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['year'])

# %%
sns.histplot(df['year'],kde=True)
plt.title("Distribution Of Year")
plt.show()

# %%
pd.set_option('display.max_rows', 150)

# %%
df
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# 5    2010   SEL  17495    25125  Silver         AUTO
# 6    2011   SEL  17000    27393    Blue         AUTO
# 7    2010   SEL  16995    21026  Silver         AUTO
# 8    2011   SES  16995    32655  Silver         AUTO
# 9    2010   SES  16995    36116  Silver         AUTO
# 10   2010   SES  16995    40539   Black         AUTO
# 11   2011   SES  16992     9199  Silver         AUTO
# 12   2011   SEL  16950     9388   Green         AUTO
# 13   2010   SES  16950    32058     Red         AUTO
# 14   2011    SE  16000    15367   White         AUTO
# 15   2011   SES  15999    16368    Blue         AUTO
# 16   2010   SEL  15999    19926  Silver         AUTO
# ...

# %% [markdown]
# ### Check the shape of the dataframe

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# ### Datatype of each column

# %%
df.dtypes
# Out:
# year             int64
# model           object
# price            int64
# mileage          int64
# color           object
# transmission    object
# dtype: object

# %% [markdown]
# ### Dataset Structure

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          150 non-null    int64
#  1   model         150 non-null    object
#  2   price         150 non-null    int64
#  3   mileage       150 non-null    int64
#  4   color         150 non-null    object
#  5   transmission  150 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 7.2+ KB

# %% [markdown]
# ### Missing value

# %%
df.isnull().sum()
# Out:
# year            0
# model           0
# price           0
# mileage         0
# color           0
# transmission    0
# dtype: int64

# %% [markdown]
# ### Duplicate values

# %%
df[df.duplicated()] #conditional statement
# Out:
# Empty DataFrame
# Columns: [year, model, price, mileage, color, transmission]
# Index: []

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Statistical Summary

# %%
df.describe()
# Out:
#               year         price        mileage
# count   150.000000    150.000000     150.000000
# mean   2008.726667  12961.933333   44260.646667
# std       2.200966   3122.481735   26982.104322
# min    2000.000000   3800.000000    4867.000000
# 25%    2008.000000  10995.000000   27200.250000
# 50%    2009.000000  13591.500000   36385.000000
# 75%    2010.000000  14904.500000   55124.500000
# max    2012.000000  21992.000000  151479.000000

# %%
df.describe(include="O")   #object or O
# Out:
#        model  color transmission
# count    150    150          150
# unique     3      9            2
# top       SE  Black         AUTO
# freq      78     35          128

# %% [markdown]
# ## Non-Graphical Analysis

# %% [markdown]
# ### Value Counts for all categorical features

# %%
df["model"].value_counts()
# Out:
# model
# SE     78
# SES    49
# SEL    23
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['year', 'model', 'price', 'mileage', 'color', 'transmission'], dtype='object')

# %%
df["transmission"].value_counts()

# %%
for col in df.select_dtypes(include="object").columns:
  display(df[col].value_counts())
  print("\n")
# Out:
# model
# SE     78
# SES    49
# SEL    23
# Name: count, dtype: int64
# color
# Black     35
# Silver    32
# Red       25
# Blue      17
# Gray      16
# White     16
# Green      5
# Yellow     3
# Gold       1
# Name: count, dtype: int64
# transmission
# AUTO      128
# MANUAL     22
# Name: count, dtype: int64

# %% [markdown]
# ### Unique Attributes for all categorical features

# %%
for col in df.select_dtypes(include="object").columns:
  print(col,"has",df[col].nunique(),"values")
  display(df[col].unique())
  print("\n")
# Out:
# model has 3 values
# array(['SEL', 'SE', 'SES'], dtype=object)
# color has 9 values
# array(['Yellow', 'Gray', 'Silver', 'White', 'Blue', 'Black', 'Green',
#        'Red', 'Gold'], dtype=object)
# transmission has 2 values
# array(['AUTO', 'MANUAL'], dtype=object)

# %% [markdown]
# ## Graphical Analysis

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### Distribution Plot
#
# - numerical data

# %%
sns.histplot(df["year"],kde=True)
plt.title("Distribution of Year")
plt.show()

# %%
for col in df.select_dtypes(include="number").columns:
  print(col)
  sns.histplot(df[col],kde=True)
  plt.show()
# Out:
# year
# price
# mileage

# %%
plt.figure(figsize=(15,5))   #width, heigh

for index,col in enumerate(df.select_dtypes(include="number").columns):
  plt.subplot(1,3,index+1)     #rows, column, position
  sns.histplot(df[col],kde=True)
  plt.title(f"Distribution of {col}")
  plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# - Year
#   - majority of used cars are from 2009 to 2010.
#
# - price
#   -

# %%
df["year"].value_counts()
# Out:
# year
# 2010    49
# 2009    42
# 2011    16
# 2008    14
# 2007    11
# 2006     6
# 2004     3
# 2000     3
# 2005     2
# 2012     1
# 2003     1
# 2002     1
# 2001     1
# Name: count, dtype: int64

# %% [markdown]
# #### Count Plot
#
# - categorical data

# %%
df.select_dtypes(include="O").columns
# Out:
# Index(['model', 'color', 'transmission'], dtype='object')

# %%
sns.countplot(x=df["model"])
plt.show()

# %%
plt.figure(figsize=(10,5))

for i,column in enumerate(df.select_dtypes(include="object").columns):

  plt.subplot(1,3,i+1)
  sns.countplot(x=df[column])
  plt.title(column)
  plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))

sns.countplot(x=df["color"],palette=df["color"].unique(), edgecolor="black")
plt.title("Color")
plt.show()
# Out:
# <ipython-input-59-fd20afd01115>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["color"],palette=df["color"].unique(), edgecolor="black")
# <ipython-input-59-fd20afd01115>:3: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   sns.countplot(x=df["color"],palette=df["color"].unique(), edgecolor="black")

# %%
df["color"].unique()
# Out:
# array(['Yellow', 'Gray', 'Silver', 'White', 'Blue', 'Black', 'Green',
#        'Red', 'Gold'], dtype=object)

# %% [markdown]
# #### Box Plot
#
#
# - distribution /  spread of the data values / outliers

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['year', 'price', 'mileage'], dtype='object')

# %%
sns.boxplot(df["price"])
plt.show()

# %%
plt.figure(figsize=(10,5))
for i, column in enumerate(df.select_dtypes(include="number").columns):
  plt.subplot(1,3,i+1)
  sns.boxplot(df[column])
  plt.title(column)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### What is an Outlier?
#
# Outlier is a data point that stands out significantly from the rest of the data. It can be an extremely high or low value compared to the other observations in a dataset. Outliers can be caused by measurement errors, natural variations in the data, or even unexpected discoveries.
#
# **Types of Outliers**
#
# There are 3 main types of outliers:
#
# - Global outliers: Stand out from the entire dataset, like a lone wolf.
# - Contextual outliers: Depend on their surroundings, like a high price product at an electronic store.
# - Collective outliers: Groups that deviate together, like a cluster of oddly high values.
#
# **How to Treat Outliers?**
#
#  - Excludes the outlier values from our analysis (values detected using IQR or Z-score method).
#  - Set the data point limit, any data point above or below that value is considered an outlier.
#  - Create groups and categorize the outliers into a specific group, making them follow the same behavior as the other points in that group. This approach is often referred to as Binning. Binning is a way of organizing data, especially in outlier detection, where we group similar items together, helping us identify and understand patterns more effectively.
#
# **How to Detect Outliers?**
#
# 1. For Normal Distributions
#
#     - Use empirical relations of Normal distribution.
#     The data points that fall below mean-3*(std) or above mean+3*(std) are outliers, where mean and sigma are the average value and standard deviation of a particular column.
#
# 2. For Skewed Distributions
#
#     - Use Inter-Quartile Range (IQR) proximity rule.
#     The data points that fall below Q1 – 1.5 IQR or above the third quartile Q3 + 1.5 IQR are outliers, where Q1 and Q3 are the 25th and 75th percentile of the dataset, respectively. IQR represents the inter-quartile range and is given by Q3 – Q1.

# %%
from scipy import stats

statistic, pvalue = stats.shapiro(df["mileage"])
if pvalue > 0.05:
  print("The data is normally distributed")
else:
  print("The data is not normally distributed")
# Out:
# The data is not normally distributed

# %%
skewness = df["price"].skew()
if skewness > 0.5:
  print("The data is positively skewed")
elif skewness < -0.5:
  print("The data is negatively skewed")
else:
  print("not strongly skewed")
# Out:
# not strongly skewed

# %%
Q1 = df["price"].quantile(0.25)
Q3 = df["price"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

# %%
outliers = df[(df["price"] <lower_bound) | (df["price"] > upper_bound)]
outliers
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO

# %%
df_new = df[~df["price"].isin(outliers["price"])]
df_new.shape
# Out:
# (146, 6)

# %% [markdown]
# #### Z-score
#
# - when the data is normally distributed
#
# ```
# (data - mean ) standard deviation
# ```

# %% [markdown]
# **Finding the boundary values**

# %%
z = (df['mileage']-df['mileage'].mean())/df['mileage'].std()

# %%
print("Mean:", round(z.mean()),",\tStd:", round(z.std()))
# Out:
# Mean: 0 ,	Std: 1

# %%
sns.histplot([z],kde=True)
plt.show()

# %%
threshold = 3
outlier = []
for i in df['mileage']:
    z = (i-df['mileage'].mean())/df['mileage'].std()
    if z > threshold:
        outlier.append(i)

print('outlier in dataset is', outlier)
# Out:
# outlier in dataset is [127327, 151479]

# %% [markdown]
# Z- Score is not preffered because data is skewed.

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# #### Mileage vs Price

# %%
df.columns
# Out:
# Index(['year', 'model', 'price', 'mileage', 'color', 'transmission'], dtype='object')

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x="mileage",y="price",data=df, color="g")
plt.show()

# %% [markdown]
# #### Model vs Price

# %%
sns.boxplot(x='model',y='price',data=df)
plt.show()

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# #### Pair Plot

# %%
sns.pairplot(df,hue="transmission")
plt.show()

# %% [markdown]
# #### Correlation

# %%
df.corr(numeric_only=True)
# Out:
#              year     price   mileage
# year     1.000000  0.845004 -0.760313
# price    0.845004  1.000000 -0.806149
# mileage -0.760313 -0.806149  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.show()

# %% [markdown]
# ## Data Profiling Library

# %%
# !pip install ydata-profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.9/390.9 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 18.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 24.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 67.3 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=65fb12f5b28a558f87177e2c9ddd1c407a4803d208ec721e33460e8ee88f817a
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...

# %%
from ydata_profiling import ProfileReport

# %%
Profile = ProfileReport(df,title="Used Car dataset Profile")

# %%
Profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.12.2&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-03-04 17:37:56.437775&quot;&gt;&lt;title&gt;Used Car dataset Profile&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
Profile.to_file("Data_Report.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## Datatypes

# %% [markdown]
# dataset=>
# int64,   float64, int64, object,  bool, datetime, object, int64, object

# %%
data = pd.DataFrame({
'Object': ['Text', 'Another text', 'Yet another text'],
'Int64': [1, 2, 3],
'Float64': [1.1, 2.2, 3.3],
'Bool': [1, 0, 1],
'DateTime64': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03']),
'TimeDelta': pd.to_timedelta(['24 hour', '2 days', '3 minutes'])
})

# %% [markdown]
# Time delta
# => it returns the duration in units => Days, hours, seconds, minutes, years, months

# %%
data
# Out:
#              Object  Int64  Float64  Bool DateTime64       TimeDelta
# 0              Text      1      1.1     1 2023-01-01 1 days 00:00:00
# 1      Another text      2      2.2     0 2023-01-02 2 days 00:00:00
# 2  Yet another text      3      3.3     1 2023-01-03 0 days 00:03:00

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Object      3 non-null      object
#  1   Int64       3 non-null      int64
#  2   Float64     3 non-null      float64
#  3   Bool        3 non-null      int64
#  4   DateTime64  3 non-null      datetime64[ns]
#  5   TimeDelta   3 non-null      timedelta64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(1), timedelta64[ns](1)
# memory usage: 276.0+ bytes

# %% [markdown]
# ### Deal with mixed types

# %% [markdown]
# #### astype() function:
# A crucial function in Pandas which is used to cast an object to a specified data type is known as astype() function. In this way, we will see how we can fix mixed data types using astype() function.

# %% [markdown]
# object > float > int

# %%
data_frame = pd.DataFrame( [['tom', 10], ['nick', '15'], ['juli', 14.8]], columns=['Name', 'Age'])

# %%
data_frame
# Out:
#    Name   Age
# 0   tom    10
# 1  nick    15
# 2  juli  14.8

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes

# %%
data_frame["Age"].astype(int)
# Out:
# 0    10
# 1    15
# 2    14
# Name: Age, dtype: int64

# %%
# Transforming mixed data types to single data type
data_frame["Age"] = data_frame["Age"].astype(int)
data_frame
# Out:
#    Name  Age
# 0   tom   10
# 1  nick   15
# 2  juli   14

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %% [markdown]
# #### Using to_numeric() function:
# The to_numeric() function is used to convert an argument to a numeric data type. In this way, we will see how we can fix mixed data types using to_numeric() function.

# %%
# Create the pandas DataFrame
data_frame = pd.DataFrame( [['tom', 10], ['nick', 'A'], ['juli', 14.8]], columns=['Name', 'Age'])
data_frame
# Out:
#    Name   Age
# 0   tom    10
# 1  nick     A
# 2  juli  14.8

# %% [markdown]
# This code will convert the 'Age' column to numeric, and if any values cannot be converted to numeric, it will coerce them to NaN (Not a Number). Here, the errors='coerce' parameter is used to handle non-numeric values gracefully by converting them to NaN.

# %%
data_frame['Age'] = pd.to_numeric(data_frame['Age'], errors='coerce')

# %%
data_frame
# Out:
#    Name   Age
# 0   tom  10.0
# 1  nick   NaN
# 2  juli  14.8

# %%
data_frame["Age"].mean()
# Out:
# 12.4

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     2 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 180.0+ bytes

# %%
data_frame.isnull().sum()
# Out:
# Name    0
# Age     1
# dtype: int64

# %% [markdown]
# ### Deal with Date Datatype

# %% [markdown]
# ```
# yyyy-mm-dd
# dd-mm-yyy
# ```
# sorting of text column ( when date column is of object datatype)
#
# ```
# aaa
# abc
# abd
# ada
# ```

# %%
data = {'Date': ['20-05-2023', '01-01-2024', '23-07-2022']}
df = pd.DataFrame(data)
df
# Out:
#          Date
# 0  20-05-2023
# 1  01-01-2024
# 2  23-07-2022

# %%
# Convert the 'Date' column to datetime data type
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True ) #when format is dd-mm-yyy

#df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 156.0 bytes

# %%
df.sort_values(by="Date",ascending=True)
# Out:
#         Date
# 2 2022-07-23
# 0 2023-05-20
# 1 2024-01-01

# %% [markdown]
# ## Duplicates handling

# %% [markdown]
# data load > duplicates check => view() to know whether you have to remove it or keep it
#
#
# - Remove
#     - When you are confirmed, that data is duplicated even the primary key value is duplicated
#     - Keep first when you need the old entries
#     - Keep last when you need the recent data
#
#
# - Keep /Don't remove
#     - when you are not sure about the context or you don't have primary key
#
# - Impute
#     - When you are sure that the duplicated value is error
#     - Impute it with placeholder or research about it

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
    'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
    'rating': [4, 4, 3.5, 15, 5]
})
df
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df.duplicated() #rows are complete duplicate
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df[df.duplicated()]
# Out:
#      brand style  rating
# 1  Yum Yum   cup     4.0

# %%
df
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %% [markdown]
# ### Drop Duplicates

# %%
df.drop_duplicates(inplace = True, keep="last")   # by default it's keep="first"

# %%
df
# Out:
#      brand style  rating
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df["brand"]
# Out:
# 1    Yum Yum
# 2    Indomie
# 3    Indomie
# 4    Indomie
# Name: brand, dtype: object

# %%
df["brand"].duplicated().sum()
# Out:
# 2

# %%
df
# Out:
#      brand style  rating
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df.drop_duplicates(subset=['brand'],keep="last")
# Out:
#      brand style  rating
# 1  Yum Yum   cup     4.0
# 4  Indomie  pack     5.0

# %%
df
# Out:
#      brand style  rating
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df.drop_duplicates(subset=['style'],keep="last") #by default keep = first
# Out:
#      brand style  rating
# 2  Indomie   cup     3.5
# 4  Indomie  pack     5.0

# %%
df
# Out:
#      brand style  rating
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df[["brand","style"]]
# Out:
#      brand style
# 1  Yum Yum   cup
# 2  Indomie   cup
# 3  Indomie  pack
# 4  Indomie  pack

# %%
df[["brand","style"]].duplicated().sum()
# Out:
# 1

# %%
df
# Out:
#      brand style  rating
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df.drop_duplicates(subset=['brand', 'style'])
# Out:
#      brand style  rating
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0

# %% [markdown]
# ### Impute the data

# %%
df
# Out:
#      brand style  rating
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df.duplicated(subset=['brand'], keep='first')
# Out:
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
df[df["brand"].duplicated()]
# Out:
#      brand style  rating
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df[df["brand"].duplicated(keep='last')]['brand']
# Out:
# 2    Indomie
# 3    Indomie
# Name: brand, dtype: object

# %%
df.loc[3,"brand"]
# Out:
# 'Indomie'

# %%
# Identify duplicates and make changes manually
df.loc[3,"brand"] = "Noodles"

# %%
df
# Out:
#      brand style  rating
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Noodles  pack    15.0
# 4  Indomie  pack     5.0

# %%
df.loc[df.duplicated(subset=['style'], keep='first'),'style'] = "Noodles"

# %%
df
# Out:
#      brand    style  rating
# 1  Yum Yum      cup     4.0
# 2  Indomie  Noodles     3.5
# 3  Noodles     pack    15.0
# 4  Indomie  Noodles     5.0

# %% [markdown]
# ### Reset index

# %%
df = pd.DataFrame({
    'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
    'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
    'rating': [4, 4, 3.5, 15, 5]
})
df
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Indomie   cup     3.5
# 2  Indomie  pack    15.0
# 3  Indomie  pack     5.0
